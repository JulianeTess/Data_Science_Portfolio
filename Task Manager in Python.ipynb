# %%
tasks = [
    {'name' : 'Write email to Jan', 'completed' : True},
    {'name' : 'Sweep front porch', 'completed' : True},
    {'name' : 'Call mom', 'completed' : False}
]

def list_tasks():
    for index, task in enumerate(tasks):
        print(str.format('{}:{}(Completed: {})', index, task['name'], task['completed']))
        
def add_task():
    task_text = input('Please add a task: ')
    new_task = {'name' : task_text, 'completed' : False}
    tasks.append(new_task)
    
def remove_task():
    list_tasks()
    remove_task = int(input('Please enter the number of the task to be removed: '))
    tasks.remove(tasks[remove_task])
    
def complete_task():
    list_tasks()
    complete_task = int(input('Please enter the number of the task that was completed: '))
    tasks[complete_task]['completed'] = True
    
menu_text = """
===================
1. List the tasks
2. Add a task
3. Remove a task
4. Mark task complete
5. Quit

What would you like to do? """

program_is_running = True

while program_is_running:
    decision = input(menu_text)
    if decision == "1":
        list_tasks()
    elif decision == "2":
        add_task()
    elif decision == "3":
        remove_task()
    elif decision == "4":
        complete_task()
    elif decision == "5":
        program_is_running = False
    else:
        print('Please choose a valid option')
# Out:
# ===================
# 1. List the tasks
# 2. Add a task
# 3. Remove a task
# 4. Mark task complete
# 5. Quit
#
# What would you like to do? 2
# Please add a task: Finish Python Final
#
# ===================
# 1. List the tasks
# 2. Add a task
# 3. Remove a task
# 4. Mark task complete
# 5. Quit
#
# What would you like to do? 1
# 0:Write email to Jan(Completed: True)
# 1:Sweep front porch(Completed: True)
# 2:Call mom(Completed: False)
# 3:Finish Python Final(Completed: False)
#
# ===================
# 1. List the tasks
# 2. Add a task
# 3. Remove a task
# 4. Mark task complete
# 5. Quit
#
# What would you like to do? 3
# 0:Write email to Jan(Completed: True)
# 1:Sweep front porch(Completed: True)
# 2:Call mom(Completed: False)
# 3:Finish Python Final(Completed: False)
# Please enter the number of the task to be removed: 0
#
# ===================
# 1. List the tasks
# 2. Add a task
# 3. Remove a task
# 4. Mark task complete
# 5. Quit
#
# What would you like to do? 4
# 0:Sweep front porch(Completed: True)
# 1:Call mom(Completed: False)
# 2:Finish Python Final(Completed: False)
# Please enter the number of the task that was completed: 2
#
# ===================
# 1. List the tasks
# 2. Add a task
# 3. Remove a task
# 4. Mark task complete
# 5. Quit
#
# What would you like to do? 1
# 0:Sweep front porch(Completed: True)
# 1:Call mom(Completed: False)
# 2:Finish Python Final(Completed: True)
#
# ===================
# 1. List the tasks
# 2. Add a task
# 3. Remove a task
# 4. Mark task complete
# 5. Quit
#
# What would you like to do? 5
